# %%
pip install datasets pandas matplotlib seaborn
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2025.4.26)

# %%
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install --upgrade datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 12.3 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 14.2 MB/s eta 0:00:00
# Installing collected packages: fsspec, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.6.0 fsspec-2025.3.0

# %%
# !pip install datasets --upgrade
from datasets import load_dataset

# Now, try loading the dataset again
dataset = load_dataset("surrey-nlp/PLOD-CW-25")
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/268 [00:00<?, ?B/s]
# PLOD-CW-25-Train.parquet:   0%|          | 0.00/343k [00:00<?, ?B/s]
# PLOD-CW-25-Test.parquet:   0%|          | 0.00/55.5k [00:00<?, ?B/s]
# PLOD-CW-25-Val.parquet:   0%|          | 0.00/35.9k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/250 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/150 [00:00<?, ? examples/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags', 'ner_tags'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags', 'ner_tags'],
#         num_rows: 250
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags', 'ner_tags'],
#         num_rows: 150
#     })
# })

# %%
print(dataset["train"][0])  # First item in the training data
# Out:
# {'tokens': ['MRR', ',', 'mortality', 'rate', 'ratio', ';', 'TBI', ',', 'traumatic', 'brain', 'injury', '.'], 'pos_tags': ['NOUN', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT', 'PROPN', 'PUNCT', 'ADJ', 'NOUN', 'NOUN', 'PUNCT'], 'ner_tags': ['B-AC', 'O', 'B-LF', 'I-LF', 'I-LF', 'O', 'B-AC', 'O', 'B-LF', 'I-LF', 'I-LF', 'O']}

# %%
import pandas as pd

# Convert train dataset to pandas dataframe
train_df = pd.DataFrame({
    'tokens': dataset['train']['tokens'],
    'pos_tags': dataset['train']['pos_tags'],
    'labels': dataset['train']['ner_tags']
})

# %%
# Convert train dataset to pandas dataframe
train_df = pd.DataFrame({
    'tokens': dataset['train']['tokens'],
    'pos_tags': dataset['train']['pos_tags'],
    'labels': dataset['train']['ner_tags']
})

# Similarly, you can also convert validation and test if needed
val_df = pd.DataFrame({
    'tokens': dataset['validation']['tokens'],
    'pos_tags': dataset['validation']['pos_tags'],
    'labels': dataset['validation']['ner_tags']
})

test_df = pd.DataFrame({
    'tokens': dataset['test']['tokens'],
    'pos_tags': dataset['test']['pos_tags'],
    'labels': dataset['test']['ner_tags']
})

# Now, check what the train dataframe looks like
print(train_df.head())
# Out:
#                                               tokens  \
# 0  [MRR, ,, mortality, rate, ratio, ;, TBI, ,, tr...
# 1  [HPC, ,, hippocampus, ;, mOFC, ,, medial, OFC,...
# 2  [In, addition, to, the, effects, on, cell, gro...
# 3  [Abbreviations, :, HC, ,, C, -, terminal, rece...
# 4   [LL, :, lower, limit, ,, UL, :, upper, limit, .]
#
#                                             pos_tags  \
# 0  [NOUN, PUNCT, NOUN, NOUN, NOUN, PUNCT, PROPN, ...
# 1  [PROPN, PUNCT, NOUN, PUNCT, NOUN, PUNCT, ADJ, ...
# 2  [ADP, NOUN, ADP, DET, NOUN, ADP, NOUN, NOUN, C...
# 3  [NOUN, PUNCT, PROPN, PUNCT, NOUN, PUNCT, ADJ, ...
# 4  [PROPN, PUNCT, ADJ, NOUN, PUNCT, PROPN, PUNCT,...
#
#                                               labels
# 0  [B-AC, O, B-LF, I-LF, I-LF, O, B-AC, O, B-LF, ...
# 1  [B-AC, O, B-LF, O, O, O, O, B-AC, O, B-AC, O, ...
# 2  [O, O, O, O, O, O, O, O, O, O, O, O, B-AC, B-A...
# 3  [O, O, B-AC, O, B-LF, I-LF, I-LF, I-LF, I-LF, ...
# 4   [B-AC, O, B-LF, I-LF, O, B-AC, O, B-LF, I-LF, O]

# %%
print("Number of training examples:", len(train_df))
print("Number of validation examples:", len(val_df))
print("Number of test examples:", len(test_df))

# %%
# Flatten all labels into one big list
all_labels = sum(train_df['labels'].tolist(), [])

# Count how many times each label appears
from collections import Counter
label_counts = Counter(all_labels)

print(label_counts)
# Out:
# Counter({'O': 62474, 'I-LF': 9525, 'B-AC': 6626, 'B-LF': 3923})

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Plot the label distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=list(label_counts.keys()), y=list(label_counts.values()))
plt.title("Label Distribution in Training Set")
plt.xlabel("Label")
plt.ylabel("Count")
plt.show()

# %%
# Find out how many tokens in each sentence
train_df['sentence_length'] = train_df['tokens'].apply(len)

# Plot a histogram
plt.figure(figsize=(8, 5))
sns.histplot(train_df['sentence_length'], bins=30, kde=True)
plt.title("Sentence Length Distribution (Number of Tokens)")
plt.xlabel("Number of Tokens")
plt.ylabel("Number of Sentences")
plt.show()

# %%
# Flatten all POS tags into one big list
all_pos_tags = sum(train_df['pos_tags'].tolist(), [])

# Count POS tags
pos_counts = Counter(all_pos_tags)

# Plot POS tag distribution
plt.figure(figsize=(10, 5))
sns.barplot(x=list(pos_counts.keys()), y=list(pos_counts.values()))
plt.xticks(rotation=45)
plt.title("POS Tag Distribution in Training Set")
plt.xlabel("POS Tag")
plt.ylabel("Count")
plt.show()

# %%
abbreviation_counts = {}

# Go through tokens and labels
for tokens, labels in zip(train_df['tokens'], train_df['labels']):
    for token, label in zip(tokens, labels):
        if label == 'B-AC':
            abbreviation_counts[token] = abbreviation_counts.get(token, 0) + 1

# Display top 10 repeated abbreviations
sorted_abbreviations = sorted(abbreviation_counts.items(), key=lambda x: x[1], reverse=True)
print(sorted_abbreviations[:10])
# Out:
# [('-', 330), ('CI', 61), ('WT', 47), ('HR', 40), ('OR', 40), ('/', 39), ('BMI', 39), ('GFP', 39), ('TB', 31), ('SD', 28)]

# %%
from collections import Counter

# Store all abbreviations
abbreviations = []

# Go through each sentence
for tokens, labels in zip(train_df['tokens'], train_df['labels']):
    for token, label in zip(tokens, labels):
        if label == 'B-AC':
            abbreviations.append(token)

# Count how many times each abbreviation appears
abbreviation_counts = Counter(abbreviations)

# Show most common repeated abbreviations
print("Top 10 repeated abbreviations:")
print(abbreviation_counts.most_common(10))
# Out:
# Top 10 repeated abbreviations:
# [('-', 330), ('CI', 61), ('WT', 47), ('HR', 40), ('OR', 40), ('/', 39), ('BMI', 39), ('GFP', 39), ('TB', 31), ('SD', 28)]

# %%
from collections import defaultdict

# Dictionary to store: abbreviation -> set of possible long forms
abbr_to_longforms = defaultdict(set)

# Loop through each sentence
for tokens, labels in zip(train_df['tokens'], train_df['labels']):
    abbr = None
    longform = []
    collecting_lf = False

    for token, label in zip(tokens, labels):
        if label == 'B-AC':
            abbr = token  # found abbreviation
        elif label == 'B-LF':
            longform = [token]
            collecting_lf = True
        elif label == 'I-LF' and collecting_lf:
            longform.append(token)
        else:
            if collecting_lf:
                if abbr:
                    lf_text = " ".join(longform)
                    abbr_to_longforms[abbr].add(lf_text)
                collecting_lf = False
                longform = []

# Filter to show only abbreviations with more than one long form
print("Abbreviations with multiple long forms:")
for abbr, lfs in abbr_to_longforms.items():
    if len(lfs) > 1:
        print(f"{abbr} → {list(lfs)}")
# Out:
# Abbreviations with multiple long forms:
# d → ['LV posterior wall thickness at end - diastole', 'aquaporin-3', 'ejection fraction', 'LV anterior wall thickness at end - diastole']
# HC → ['C - terminal receptor - binding domain', 'healthy control', 'healthy control participants']
# KD → ['glutathione compound glutathione reduced ethyl ester', 'knockdown', 'equilibrium dissociation constants', 'knock - down', 'reactive oxygen species', 'equilibrium dissociation constant']
# AMPK → ['FOrkhead boX O', 'AMP - activated protein kinase', 'double - stranded RNA']
# HbA1c → ['major adverse cardiovascular events', 'glycated hemoglobin', 'Glycated Hemoglobin', 'glycated haemoglobin', 'high - density lipoprotein', 'hemoglobin A1c']
# IR → ['ionotropic receptor', 'homeostasis model assessment of insulin resistance', 'incidence rate', 'insulin resistance', 'homeostatic model assessment of insulin resistance']
# TCR → ['high - throughput sequencing of TCR repertoires', 'T cell receptor', 'T - cell receptor']
# BCG → ['diphtheria – pertussis – tetanus', 'adriamycin']
# HR → ['Barcelona Clinic Liver Cancer', 'left ventricle', 'heart rate', 'hazard ratio', 'highly reducing']
# OR → ['Confidence Intervals', 'Odds ratio', 'positive and negative predictive values', 'odds ratio', 'confidence interval', 'Odds Ratio']
# ALT → ['Alanine Aminotransferase', 'cyclic GMP - AMP synthase', 'aspartate aminotransferase', 'cGAS)–stimulator of interferon genes', 'gamma - glutamyl transferase', 'creatinine', 'alanine aminotransferase']
# AST → ['international normalized ratio', 'aspartate aminotransferase', 'total cholesterol', 'alanine aminotransferase']
# ART → ['Antiretroviral Therapy', 'antiretroviral therapy', 'World Health Organization', 'peripheral blood mononuclear cells', 'antiretroviral treatment', 'assisted reproductive technology', 'clinically driven monitoring']
# NNRTI → ['non - nucleoside reverse transcriptase inhibitor', 'pretreatment drug resistance']
# NRTI → ['combination antiretroviral therapy', 'nucleoside reverse transcriptase inhibitor']
# VL → ['antiretroviral therapy', 'viral load']
# HF → ['health facility', 'heart failure', 'high frequency', 'Health Facility', 'left ventricular ejection fraction', 'high - fat']
# KO → ['bovine type II collagen', 'knock - out', 'quantitative polymerase chain reaction', 'wildtype', 'knockout']
# WT → ['wild type', 'wild - type', 'Columbia-0', 'chow diet', 'RGL knock - in']
# BF → ['best frequency', 'bone mineral content']
# CF → ['body - mass - index', 'characteristic frequency']
# LH → ['lateral hypothalamic area', 'follicle - stimulating hormone']
# WPRE → ['woodchuck hepatitis virus posttranscriptional control element', 'bovine growth hormone polyadenylation sequence']
# GAPDH → ['acetaminophen', 'glyceraldehyde 3 - phosphate dehydrogenase']
# BMI → ['waist circumference', 'body mass index', 'forced expiratory volume in the first second', 'Body Mass Index', 'genetic risk score', 'daytime sleepiness']
# TB → ['tuberculosis', 'multidrug - resistant', 'drug - resistant tuberculosis', 'multidrug - resistant tuberculosis', 'people living with HIV', 'Tuberculosis', 'drug susceptibility testing', 'Médecins Sans Frontières', 'rifampicin']
# AUC → ['relative enhancement', 'Area under the Curve', 'area under the receiver operating characteristics curve', 'receiver operator characteristics', 'positive predictive value', 'area under the curve', 'area under the receiver operating characteristic curve']
# ANC → ['antenatal care', 'anteriormost NC', 'Antenatal care', 'intermittent preventive treatment with sulfadoxine - pyrimethamine']
# DMRs → ['CpG islands', 'Gene ontology']
# LN → ['Lymph node', 'linear – nonlinear']
# MDA → ['malondialdehyde acetaldehyde', 'malondialdehyde']
# ER → ['endoplasmic reticulum', 'uridine diphosphate', 'estrogen receptor']
# CKD → ['cardiovascular disease', 'end stage renal disease', 'chronic kidney disease', 'diabetic nephropathy', 'congenital anomalies of the kidney and urinary tract']
# SNPs → ['minor allele frequency', 'creatine kinase', 'Single Nucleotide Polymorphism Database']
# EEG → ['electroencephalography', 'electrocorticography']
# SM → ['secondary metabolite', 'SEHER Mitra', 'sphingomyelin']
# RR → ['relative risk', 'risk ratio', 'respiratory rate', 'respiration - related rhythm']
# PPV → ['negative predictive values', 'negative predictive value', 'anatomical therapeutic chemical']
# GFP → ['tdTomato', 'the peel of green fruit', 'green fluorescent proteins', 'endoplasmic reticulum', 'green fluorescent protein']
# L3 → ['third instar', 'third larval stage']
# PCR → ['Polymerase Chain Reaction', 'quantitative real - time PCR', 'reverse transcription PCR', 'quantitative reverse transcription PCR', 'inhibin subunit beta A', 'real - time quantitative reverse transcription PCR', 'polymerase chain reaction', 'reverse transcription - polymerase chain reaction']
# RFP → ['red fluorescent protein', 'isoniazid']
# IQR → ['interquartile range', 'Interquartile range']
# SRH → ['sexual and reproductive health', 'self - rated health']
# CHWs → ['prevention of mother - to - child HIV transmission', 'weight - for - length Z - scores']
# ECG → ['electrocardiography', 'electrocardiogram']
# MET → ['metastatic tumor diameter', 'proto - oncogene c - Met']
# PBS → ['acetyl - VVVVVVD', 'phosphate buffered saline', 'phosphate - buffered saline']
# AZ → ['methyl red', 'active zone']
# MR → ['mendelian randomisation', 'computed tomography', 'Mendelian randomization', 'congo red']
# M → ['3 months old', '26 months old']
# LV → ['LV internal diameter at end - diastole', 'left ventricle', 'cardiac myosin binding protein C']
# ROS → ['glutathione', 'reactive oxygen species']
# TG → ['trigeminal ganglion', 'triglycerides', 'low - density lipoprotein', 'Triglycerides', 'triglyceride', 'transgenic']
# LPS → ['intestinal fatty acid binding protein', 'lipopolysaccharides', 'lipopolysaccharide']
# HCV → ['lost to follow - up', 'hepatitis C virus', 'genotypes', 'hepatitis B virus']
# miRNAs → ['short interfering RNAs', 'Double - Stranded RNA - Specific Endoribonuclease', 'familial adenomatous polyposis']
# TTP → ['time - to - peak', 'receiver operating characteristic']
# FGF23 → ['fibroblast growth factor 23', 'N - terminal pro - B - type natriuretic peptide']
# DIC → ['differential interference contrast', 'disseminated intravascular coagulation', 'decline in intrinsic capacity']
# IL-6 → ['carbon tetrachloride', 'growth differentiation factor 15', 'tumour necrosis factor α']
# FIT → ['fecal immunochemical test', 'Australian Fans in Training']
# BMDM → ['bone marrow – derived macrophage', 'bone marrow – derived MΦ']
# HS → ['high salt', 'heat shock']
# ns → ['nonsilencing', 'not significant']
# PCa → ['Prostate cancer', 'prostate cancer']
# WHO → ['pre - school age children', 'Guillain – Barré syndrome', 'National Center for Health Statistics', "United Nations Children 's Fund", 'United Nations International Children ’s Emergency Fund', 'global health sector strategy', 'World Health Organization']
# SOFA → ['Sequential Organ failure Assessment', 'sequential organ failure assessment']
# AIS → ['abbreviated injury scale', 'Injury Severity Score']
# SAP → ['systolic arterial blood pressure', 'diastolic arterial pressure']
# ICU → ['Intensive care unit', 'Intensive Care Unit', 'intensive care unit', 'mechanical ventilation']
# LOS → ['length of stay', 'lipooligosaccharide', 'Length of stay']
# siRNAs → ['double - stranded RNAs', 'small interfering RNAs']
# BC → ['breast cancer', 'betweenness centrality']
# CI → ['Cavitation Index', '95 % confidence interval', 'competitive index', 'mean residence time', 'concentration curve', 'Confidence Interval', 'confidence interval']
# IMD → ['Index of Multiple Deprivation', 'index of multiple deprivation']
# PA → ['phthalic acid', 'protein aggregate', 'phase angle']
# BM → ['peripheral blood', 'bone marrow', 'body mass']
# IM → ['intermodulation', 'intramuscular', 'inner membrane', 'composite interval mapping']
# SA → ['spine apparatus', 'suture anchor', 'cesarean delivery']
# TS → ['treatment success', 'transosseous suture']
# HT → ['dyslipidemia', 'serotonin', 'hypertensive', 'diabetes mellitus', '3 - 4 - Dihydroxyphenylacetic acid']
# DM → ['Barcelona Clinic Liver Cancer', 'Diabetes Mellitus type 2', 'diabetes mellitus', 'serum creatinine', 'chronic obstructive pulmonary disease']
# COPD → ['chronic obstructive pulmonary disease', 'transient ischemic attack', 'Chronic Obstructive Pulmonary Disease', 'end - stage renal disease']
# LF → ['low frequency', 'lethal toxin', 'High Frequency']
# I → ['angiotensin receptor blocker', 'angiotensin - converting enzyme inhibitor', 'dorsal root ganglia', 'carboxy - terminal telopeptide of type I collagen']
# D1 → ['G - protein coupled receptor 161', 'day 1', 'first dry season']
# IPP → ['isopentenyl pyrophosphate', '3 - hydroxy-3 - methylglutaryl - CoA']
# HRV → ['Low Frequency', 'sudden cardiac death']
# D2 → ['day 2', 'second dry season']
# GO → ['gene ontology', 'Gene Ontology', 'differentially expressed genes']
# CFS → ['graph strength', 'cross - frequency PS']
# HCC → ['Total tumor volume', 'hepatocellular carcinoma', 'hepatitis B virus']
# CO → ['cardiac output', 'stroke volume']
# AGT → ['sterol carrier protein 2', 'enhanced green fluorescent protein']
# CASCADE → ['Kathleen Cuningham Foundation Consortium for Research into Familial Breast Cancer', 'prospective community - based rapid autopsy program']
# RIF → ['isoniazid', 'rifampicin']
# RT → ['Retention Time', 'high - intensity interval training', 'radiation']
# TP → ['true negatives', 'total phosphorus']
# AP → ['alkaline phosphatase', 'arterial pressure', 'available phosphorus']
# SMC → ['smooth muscle cell', 'soil moisture content']
# DI → ['defective interfering', 'Dietary Index']
# IC50 → ['nuclear factor κB', 'half - maximal inhibitory concentration']
# ChIP → ['chromatin immunoprecipitation', 'transcription start site']
# COVID-19 → ['coronavirus disease 2019', 'cardiac magnetic resonance imaging', 'World Health Organization', 'severe acute respiratory syndrome coronavirus-2']
# CoV-2 → ['severe acute respiratory syndrome coronavirus 2', 'coronavirus disease 2019', 'Coronavirus Disease 2019', 'Severe Acute Respiratory Syndrome Coronavirus 2', 'credible interval']
# SD → ['standard deviation', 'standard drink', 'standard deviation of regression', 'standard deviations', 'interquartile range', 'short - day']
# ED → ['emergency department', 'Emergency Department']
# NPV → ['receiver operator characteristic', 'negative predictive value']
# SBP → ['diastolic blood pressure', 'systolic blood pressure']
# LDL → ['low - density lipoprotein', 'total cholesterol', 'high - density lipoprotein']
# HDL → ['high - density lipoprotein', 'C - reactive protein', 'high density lipoprotein']
# CRP → ['haemoglobin A1c', 'C - reactive protein', 'high - sensitivity C - reactive protein', 'high sensitivity C - reactive protein']
# ECM → ['alpha - smooth muscle actin', 'extra cellular matrix']
# NSAID → ['chronic kidney disease', 'angiotensin - converting - enzyme inhibitor']
# CIs → ['confidence intervals', 'standard error']
# DN → ['dominant - negative', 'hypertensive nephropathy']
# MAP → ['upper arm', 'high - density microarray patch']
# QALY → ['quality - adjusted life years', 'quality - adjusted life year']
# CM → ['cardiomyocyte', 'Alzheimer disease – signature cerebral glucose metabolism', 'policy advocacy']
# CT → ['clotting time', 'constant time', 'single photon emission computerized tomography', 'Cancer / Testis', 'Alzheimer disease – signature cortical thickness', 'computer tomography']
# INR → ['initiator', 'international normalized ratio']
# MOR → ['left , MOR activity remained', 'Proportional Change in Variance']
# TC → ['triglycerides', 'after egg laying', 'Total Cholesterol', 'total cholesterol', 'triglyceride', 'low - density lipoprotein - cholesterol']
# PMI → ['overall survival', 'President ’s Malaria Initiative', 'prioritized memory item']
# OS → ['overall survival', 'cancer - specific survival']
# lobe → ['nuclease lobe', 'α - helical recognition lobe']
# sgRNA → ['single - guide RNA', 'subgenomic RNA']
# CVD → ['Medical Research Council Integrative Epidemiology Unit', 'cancer therapy – related cardiac dysfunction', 'cardiovascular disease', 'Cardiovascular disease', 'type 2 diabetes', 'quality - adjusted life years']
# AF → ['body mass index', 'atrial fibrillation']
# MRI → ['positron emission tomography', 'diffusion - weighted imaging', 'magnetic resonance imaging']
# PET → ['mild cognitive impairment', 'myocardial blood flow']
# ICER → ['incremental cost - effectiveness ratio', 'Incremental cost - effectiveness ratio']
# EF1 → ['Human elongation factor-1 alpha promoter', 'fibroblast growth factor 7']
# HNF4α → ['insulin receptor substrate 2', 'hepatocyte nuclear factor 4 - alpha']
# qPCR → ['reverse transcription quantitative PCR', 'reverse transcriptase - quantitative PCR', 'quantitative real - time PCR', 'real - time quantitative polymerase chain reaction', 'reverse transcriptase quantitative PCR', 'telomere - associated repetitive element 2', 'quantitative PCR']
# RU → ['relative unit', 'standard of care']
# SC → ['subcutaneous', 'STIM1 - CC1 construct', 'spontaneous conception']
# MS → ['liquid chromatography – mass spectrometry', 'hydrogen / deuterium exchange mass spectrometry', 'nuclear magnetic resonance', 'far - ultraviolet', 'mass spectrometry', 'matrix - assisted laser desorption / ionization time - of - flight mass spectrometry', 'multiple sclerosis', 'overweight']
# AFP → ['alpha - fetoprotein', 'alanine aminotransferase']
# DAP → ['daptomycin', 'left ventricular systolic pressure']
# PLA → ['ring - opening polymerization', 'proximity ligation assay']
# AA → ['arachidonic acid', 'European Americans', 'artesunate - amodiaquine', 'aortic arch', 'proximal tubular epithelial cells']
# AD → ['acetylcholinesterase inhibitors', 'acute - on - chronic liver failure', "Alzheimer 's disease", 'Aguadulce', 'aggregate data', 'Alzheimer ’s Disease Genetics Consortium']
# CD → ['body weight', 'cluster of differentiation', 'synchrotron radiation circular dichroism', 'ulcerative colitis', 'colitis activity index']
# CFU → ['colony - forming unit', 'colony forming unit']
# κB → ['peripheral blood mononuclear cells', 'caffeic acid phenethyl ester']
# CS → ['complex spike', 'objective structured clinical examination', 'complex spikes']
# DD → ['constant darkness', 'metabolic syndrome', 'diversity - dependent']
# LTL → ['telomere to single - gene copy ratio', 'Leukocyte Telomere Length']
# PR → ['prevalence ratio', 'quantitative Real Time Polymerase Chain Reaction', 'progesterone receptor']
# MVPA → ['moderate to vigorous physical activity', 'moderate - to - vigorous physical activity']
# TIA → ['transient ischemic attack', 'intracerebral hemorrhage']
# FEL → ['Spore Wall Maturation 1', 'fixed - effects likelihood']
# MEME → ['Dulbecco ’s Modified Eagle Medium', 'mixed - effects model of evolution']
# SP → ['specificity', 'intermittent preventive treatment in pregnancy', 'synaptopodin']
# BP → ['bowel preparation', 'blood pressure', 'adenoma detection rate']
# TSS → ['transcription start site', 'total suspended solids']
# NLR → ['positive predictive value', 'neutrophil - to - lymphocyte ratio', 'colorectal liver metastasis']
# MPR → ['medication possession ratio', 'cation - independent mannose 6 - phosphate receptor']
# II → ['Integrated Nutrition and Health Program–“Intervention', 'T cell receptor', 'Simplified Acute Physiology Score']
# PS → ['phase synchrony', 'hydrolyzed native potato starch']
# PSM → ['Control non - infected', 'propensity score matching']
# BV → ['biliverdin', 'rapid diagnostic tests']
# CNS → ['microcephaly with structural brain defects', 'von Hippel - Lindau disease']
# SAC → ['preventive chemotherapy and transmission control', 'school age children']
# PCT → ['procalcitonin', 'mass drug administration']
# PI → ['pulse interval', 'propidium iodide']
# SAM → ['Therapeutic Feeding Center', 'EF - hand and sterile alpha motif domain']
# PD → ['Parkinson ’s disease', 'lateral pyloric', 'Parkinson disease']
# MI → ['bone marrow', 'mutual information', 'myocardial infarction', 'Episodes of care', 'coronary artery disease']
# TOM → ['outer mitochondrial membrane', 'translocase of the outer membrane']
# TGFβ → ['phosphatidylinositol 3 kinase', 'transforming growth factor - β', 'PI3K)/v - akt murine thymoma viral oncogene homolog 1', 'Smad - binding element', 'Renin mRNA']
# APX → ['guaiacol peroxidase', 'glutathione reductase']
# GR → ['thioredoxin', 'catalase']
# EBV → ['Kaposi ’s sarcoma - associated herpesvirus', 'microsatellite instability', 'Epstein – Barr virus']
# SEEG → ['stereoelectroencephalography', 'stereotactic electroencephalography']
# BPD → ['bronchopulmonary dysplasia', 'borderline personality disorder', 'Borderline Personality Disorder']
# cko → ['conditional knockout', 'skeletal muscle – specific Lmna - cko mice']
# HSA → ['human alpha - skeletal actin', 'heat stable antigen', 'human serum albumin']
# NA → ['covalently closed circular DNA', 'noradrenaline']
# MIC → ['AmpC beta - lactamase', 'minimum inhibitory concentration']
# UC → ['Modified Truelove and Witts activity index', 'Wharton ’s Jelly', 'type 1 diabetes']
# T1D → ['Adaptive Study of IL-2 Dose on Regulatory T Cells in Type 1 Diabetes', 'rheumatoid arthritis']
# RA → ['Restricted Areas', 'robust nucleus of the arcopallium', 'celiac disease']
# IL-22 → ['natural killer', 'interleukin-22']
# STAT3 → ['microbubbles', 'signal transducer and activator of transcription 3']
# CK → ['creatine kinase', 'creatinine kinase', 'Cytokinin']
# CHD → ['confidence interval', 'coronary heart diseases', 'chronic obstructive pulmonary disease', 'coronary heart disease']
# Hb → ['haemoglobin', 'hemoglobin', 'haemoglobin concentration']
# WBC → ['C - reactive protein', 'white blood count', 'white blood cell']
# fMRI → ['impulse response function', 'functional MRI']
# BCS → ['body condition score', 'British Cohort Study']
# SMCs → ['platelet derived growth factor receptor beta', 'fibroblasts']
# BAT → ['Stearoyl - Coenzyme A Desaturase 2', 'protein kinase A']
# PAC → ['phase - amplitude coupling', 'phase – amplitude coupling']
# ALSPAC → ['Manchester Asthma and Allergy Study', 'Avon Longitudinal Study of Parents and Children']
# MCS → ['Millennium Cohort Study', 'mental component summary score']
# HPV → ['dual - stained', 'women living with HIV']
# CMV → ['ulcerative colitis', 'polymerase chain reaction']
# KF → ['DNA - binding domain', 'upstream activating sequence']
# CANONIC → ['the European Association for the Study of the Liver', 'Chronic Liver Failure Consortium']
# C → ['high density lipoprotein - cholesterol', 'high - density lipoprotein cholesterol', 'low - density lipoprotein cholesterol', 'acute decompensation', 'septation initiation network', 'low density lipoprotein - cholesterol', 'proliferating B cell progenitor', 'high - density lipoprotein - cholesterol']
# ROI → ['return on investment', 'region of interest']
# ctDNA → ['hazard ratio', 'circulating tumor DNA']
# BMDC → ['magnetic activated cell sorter', 'bone marrow – derived DC']
# Cas9 → ['CRISPR - associated 9', 'clustered regularly interspersed short palindromic repeats – CRISPR - associated protein 9']
# OHT → ['Ocular hypertension', '4 - hydroxy - tamoxifen']
# MUA → ['multiunit activity', 'multi - unit activity']
# RFS → ['recurrence - free survival', 'replicate frequency spectrum']
# GDM → ['gestational diabetes', 'gestational diabetes mellitus', 'eicosapentaenoic acid']
# PE → ['preeclampsia', 'intra - uterine growth restriction']
# GSH → ['reduced glutathione', 'buthionine sulfoximine']
# IPF → ['acute respiratory distress syndrome', 'idiopathic interstitial pneumonia']
# MD → ['atomic force microscopy', 'ventral anterior nucleus', 'nicotinic acetylcholine receptor', 'mean difference']
# ABCG2 → ['ATP - binding cassette subfamily G 2', 'Breast Cancer Resistance Protein']
# IFN → ['interleukin', 'IFN - stimulated genes', 'ribavirin', 'interferon']
# ML → ['logistic regression', 'maximum likelihood', 'chloroplast - like']
# US → ['High - grade Squamous Intraepithelial Lesion', 'African Americans']
# IPV → ['human embryonic kidney cell line 293A', 'intimate partner violence']
# IPD → ['invasive pneumococcal disease', 'isoleucine - serine - valine', 'individual participant data']
# NS → ['nutri - score', 'normal salt', 'neural stage', 'not significant']
# CDS → ['coding sequence', 'coding DNA sequence', 'micrococcal nuclease']
# PWD → ['the Revised Memory and Behaviour Problems Checklist', 'Prevalence - Adjusted Bias - Adjusted Kappa']
# P → ['anterior – posterior', 'JADE - Personalized']
# BE → ['nonsteroidal anti - inflammatory drugs', 'Boundary enhancer']
# FF → ['fresh frozen', 'feed - forward']
# lncRNA → ['long noncoding RNA', 'cAMP response element - binding protein']
# HMGR → ['3 - hydroxy-3 - methylglutaryl - CoA reductase', '3 - hydroxy-3 - methyl glutaryl CoA reductase']
# PT → ['parietopsin', 'prothrombin time', 'Primary tumor']
# RCT → ['randomized controlled trial', 'randomised controlled trial']
# ACR → ['estimated glomerular filtration rate', 'albumin : creatinine ratio']
# eGFR → ['estimated glomerular filtration rate', 'chronic kidney disease']
# seq → ['single - cell RNA sequencing', 'chromatin immunoprecipitation sequencing', 'RNA sequencing', 'Gene Expression Omnibus', 'dual - barcoded shotgun expression library sequencing', 'single cell RNA sequencing', 'FAIRE sequencing']
# D → ['differentiating B cell progenitor', 'recombinant type - I IFN - alpha']
# TAZ → ['transcriptional coactivator with PDZ - binding motif', 'Transcriptional coactivator with PDZ - binding motif']
# YAP → ['yes - associated protein', 'Yes - associated protein']
# CAD → ['androgen dependent tissue factor pathway inhibitor regulating protein', 'coronary artery disease', 'peripheral arterial disease']
# LVEF → ['left ventricle ejection fraction', 'left ventricular ejection fraction']
# Sp → ['specificity', 'Schizosaccharomyces pombe']
# CRC → ['colorectal cancer', 'locally advanced rectal cancer']
# FDR → ['first - degree relative', 'false discovery rate']
# DR1 → ['HLA - DR1', 'DRB1 * 0101']
# H&E → ['intraductal carcinoma of the prostate', 'high - grade prostatic intraepithelial neoplasia']
# Aβ → ['amyloid - beta', 'amyloid precursor protein', 'scrambled']
# ppm → ['part per million', 'parts per million']
# ROC → ['receiver operating characteristic', 'receiver operating characteristics']
# Se → ['sensitivity', 'specificity']
# OB → ['olfactory bulb', 'no bud']
# LAM → ['lymphangioleiomyomatosis', 'tuberculosis', 'lipoarabinomannan assay', 'people living with HIV']
# EC → ['Lynch syndrome', 'endothelial cell']
# TF → ['time - frequency', 'transferrin']
# PC → ['primary care', 'diacylglyceryl - N , N , N - trimethylhomoserine']
# PP → ['per - protocol', 'adaptation index', 'posterior probability']
# HV → ['Hepatic vein', 'healthy volunteer']
# PV → ['poliovirus', 'portal vein']
# SE → ['sleep efficiency', 'standard education', 'standard error']
# SUP → ['superior optic nerve', 'superior']
# RSA → ['respiratory sinus arrhythmia', 'representational similarity analysis']
# LBD → ['glutathione S - transferase', 'ligand - binding domain']
# HIV → ['Human Immunodeficiency Virus', 'renal transplant recipients']
# FEV1 → ['intravenous', 'forced vital capacity', '1st s forced expiratory volume', 'Forced Expiratory Volume in 1 second']
# MAVS → ['mitochondrial antiviral signaling protein', 'full - length MAVS']
# DOR → ['false positive rate', 'left , DOR activity remained']
# EN → ['Endangered', 'Enteral nutrition']
# TPN → ['total parenteral nutrition', 'Total parenteral nutrition']
# OD → ['optical density', 'odds ratios']
# DSS → ['dextran sodium sulfate', 'postsynaptic density']
# CML → ['pyrraline', 'gastrointestinal stromal tumors']
# BMP → ['Bone Morphogenetic Protein', 'paired box 7']
# tMRCA → ['University of Massachusetts Amherst', 'time to the most recent common ancestor']
# RF → ['receptive field', 'support vector machine']
# YFP → ['yellow fluorescent protein', 'green fluorescent protein']
# CD4 → ['cluster of differentiation 4', 'people living with HIV / AIDS']
# IHD → ['ischemic heart disease', 'potential impact fraction']
# TIM-1 → ['tissue inhibitor of metalloproteinase-1', 'renin – angiotensin system']
# FFM → ['Fat Free Mass', 'body fat']
# GFR → ['serum creatinine', 'glomerular filtration rate']
# RM → ['repetition maximum', 'Reina Mora']
# hpi → ['hours post infection', 'peptidoglycan']
# T3 → ['thyroxine', 'treatment group 3']
# VOCs → ['relative humidity', 'COVID-19 Genomics UK Consortium']
# SVM → ['logistic regression', 'Random Forests']
# WC → ['waist circumference', 'body mass index', 'waist - hip ratio', 'odds ratios', 'Waist Circumference', 'fasting blood glucose']
# IRES → ['internal ribosome entry site', 'woodchuck posttranscriptional regulatory element']
# PCIs → ['standard deviation', 'acute coronary syndrome']
# A → ['postoperative', 'magnetic resonance arthrography']
# FP → ['false negatives', 'the peel of red fruit']
# FS → ['okadaic acid', 'the sarcocarp of red fruit']
# NT → ['N terminus', 'Near Threatened', 'neural tube']
# PaO2 → ['partial pressure of arterial oxygen', 'fraction of inspired oxygen']
# GWAS → ['alkaline phosphatase', 'genome - wide association study', 'PHEnome Scan Analysis Tool']
# LTP → ['high - frequency stimulations', 'Crossveinless - d']
# N1+/-;N2+/- → ['Notch1', 'Notch2']
# PDGFRα → ['small interfering RNA', 'inhibitory RNA']
# NGS → ['polymerase chain reaction', 'next - generation sequencing']
# AAGL → ['Elevating Gynecologic Surgery , founded as American Association of Gynecologic Laparoscopists', 'American College of Obstetricians and Gynecologists']
# EF → ['ejection fraction', 'fractional shortening']
# BTB → ['Bric - a - brac , Tramtrack and Broad)/Kelch', 'intervening region']
# NF1 → ['succinate dehydrogenase', 'neurofibromatosis type 1']
# PB → ['chopped paper napkins', 'heart failure']
# MVA → ['carbonyl cyanide 4-(trifluoromethoxy ) phenylhydrazone', 'santalene synthase']
# FPP → ['farnesyl pyrophosphate', 'geranylgeranyl pyrophosphate']
# L1 → ['first larval stage', 'PD-1 ligand']
# TR → ['echo time', 'time - velocity integral']
# TE → ['field of view', 'translational efficiency']
# RP → ['ribosomal protein', 'yeast metabolic cycle']
# TH → ['putamen', 'phosphorylated c - Jun protein']
# VBAC → ['vaginal birth after previous cesarean', 'vaginal birth after cesarean']
# COR → ['adjusted odds ratio', 'crude odds ratio']
# HBV → ['hepatitis B virus', 'human immunodeficiency virus']
# CN → ['Control infected', 'cerulein']
# CIRT → ['prostate - specific antigen', 'androgen - deprivation therapy', 'carbon ion radiotherapy']
# PDGF → ['PI3K)–Protein kinase B', 'Phosphoinositide 3 - kinase']
# LVMI → ['Left ventricular mass index', 'late gadolinium enhancement', 'left ventricular mass index']
# LAVI → ['Left atrium volume index', 'left atrial volume index']
# PMC → ['positive predictive value', 'polyvalent meningococcal conjugate']
# LP → ['leader protein', 'pyloric constrictor']
# AQ → ['artesunate', 'PK', 'sulfadoxine - pyrimethamine']
# MTB → ['Mycobacterium tuberculosis', 'methylthio - D - xylose']
# TLR → ['non - ulcer dyspepsia', 'toll - like receptor']
# DS → ['human chromosome 21', 'dorsal striatum', 'diameter stenosis']
# iRFP → ['Histone 2B', 'infrared fluorescent protein']
# CR → ['Crown root', 'Critically Endangered']
# IAA → ['Auxin', 'indole-3 - acetic acid']
# CCR2 → ['monocytes', 'macrophages']
# - → ['tumor necrosis factor alpha', "Complete Freund 's adjuvant"]
# LAD → ['left atrial dimension', 'left anterior descending']
# TST → ['total sleep time', 'Tuberculin Skin Test']
# PECAM-1 → ['cluster of differentiation', 'platelet / endothelial cell adhesion molecule 1']
# GFAP → ['intermediate filament', 'myelin basic protein', 'ionized calcium binding adaptor molecule 1(Iba1']
# AOR → ['adjusted odds ratio', 'confidence interval']
# DWI → ['diffusion - weighted imaging', 'apparent diffusion coefficient']
# ADC → ['basal ganglia and thalami', 'posterior limb of the internal capsule']
# M0 → ['the moment magnitude', 'the seismic moment', 'The seismic moment']
# FFA → ['α - linolenate', 'γ - linolenate']
# cys → ['cystatin C', 'creatinine and cystatin C']
# WGA → ['wheat germ agglutinin', 'weeks of gestational age']
# EB → ['early bud', 'pyrazinamide']
# SSB → ['neurofibromatosis 2', 'sugar - sweetened beverage']
# CBI → ['Confirmatory Factor Analysis', 'Exploratory Factor Analysis']
# Ada → ['green fluorescent protein', 'α - Adaptin']
# CLA → ['Conjugated linoleic acid', 'Rumenic acid']
# Pf → ['low - density', 'high - density']

# %%
from collections import Counter

# Extract all long forms as phrases
long_forms = []

for tokens, labels in zip(train_df['tokens'], train_df['labels']):
    lf = []
    collecting = False
    for token, label in zip(tokens, labels):
        if label == 'B-LF':
            lf = [token]
            collecting = True
        elif label == 'I-LF' and collecting:
            lf.append(token)
        else:
            if collecting:
                long_forms.append(" ".join(lf))
                collecting = False
    if collecting and lf:
        long_forms.append(" ".join(lf))  # catch at end of sentence

# Count repeated long forms
lf_counts = Counter(long_forms)
print("Top 10 repeated long forms:")
print(lf_counts.most_common(10))
# Out:
# Top 10 repeated long forms:
# [('confidence interval', 34), ('wild - type', 28), ('body mass index', 28), ('green fluorescent protein', 23), ('hazard ratio', 21), ('standard deviation', 18), ('odds ratio', 16), ('knockout', 14), ('World Health Organization', 12), ('antiretroviral therapy', 12)]

# %%
import re
from collections import Counter

abbreviations = []

for tokens, labels in zip(train_df['tokens'], train_df['labels']):
    for token, label in zip(tokens, labels):
        if label == 'B-AC':
            # Only include alphabetic or alphanumeric abbreviations (ignore '-', '/')
            if re.match(r'^[A-Za-z0-9]+$', token):
                abbreviations.append(token)

abbreviation_counts = Counter(abbreviations)

print("Top 10 repeated abbreviations (cleaned):")
print(abbreviation_counts.most_common(10))
# Out:
# Top 10 repeated abbreviations (cleaned):
# [('CI', 61), ('WT', 47), ('HR', 40), ('OR', 40), ('BMI', 39), ('GFP', 39), ('TB', 31), ('SD', 28), ('C', 27), ('MS', 24)]

# %%
import matplotlib.pyplot as plt

# Final corrected data
labels = ['1 token', '2 tokens', '3 tokens', '4 tokens', '5+ tokens']
outer_vals = [36778, 90058, 87429, 29939, 22147]  # Total frequency (outer)
inner_vals = [5938, 13888, 15969, 8069, 8099]     # Unique forms (inner)

# Set color order: green, orange, grey, yellow, blue
colors = ['#4CAF50', '#FF9800', '#9E9E9E', '#FFEB3B', '#2196F3']
explode = [0.05] * len(labels)  # Explode all outer slices

# Start plotting
fig, ax = plt.subplots(figsize=(8, 6))

# Outer ring – total frequency, clockwise
wedges_outer, _, autotexts_outer = ax.pie(
    outer_vals,
    radius=1.0,
    labels=None,
    colors=colors,
    explode=explode,
    autopct=lambda pct: f"{int(pct * sum(outer_vals) / 100)}",
    pctdistance=0.85,
    startangle=90,
    counterclock=False,
    wedgeprops=dict(width=0.3, edgecolor='white')
)

# Inner ring – unique forms, solid center, clockwise
wedges_inner, _, autotexts_inner = ax.pie(
    inner_vals,
    radius=0.7,
    labels=None,
    colors=colors,
    startangle=90,
    counterclock=False,
    autopct=lambda pct: f"{int(pct * sum(inner_vals) / 100)}",
    pctdistance=0.6,
    wedgeprops=dict(edgecolor='white')
)

# Title and legend
ax.set_title("PLOD Token Length Distribution\nInner: Unique Forms | Outer: Total Frequency", fontsize=11)
ax.legend(wedges_outer, labels, title="Token Length", loc="center left", bbox_to_anchor=(1, 0.5), fontsize=9)
ax.axis('equal')  # Keep pie chart circular

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Final verified values
labels = ['2 chars', '3 chars', '4 chars', '5 chars', '6+ chars']
outer_vals = [103527, 190854, 84448, 37416, 33021]  # Total frequency
inner_vals = [1422, 9214, 10418, 5722, 6892]         # Unique forms

# Color scheme: green, orange, grey, yellow, blue
colors = ['#4CAF50', '#FF9800', '#9E9E9E', '#FFEB3B', '#2196F3']
explode = [0.05] * len(labels)

# Create plot
fig, ax = plt.subplots(figsize=(8, 6))

# Outer ring: total frequency (exploded)
wedges_outer, _, autotexts_outer = ax.pie(
    outer_vals,
    radius=1.0,
    labels=None,
    colors=colors,
    explode=explode,
    autopct=lambda pct: f"{round(pct * sum(outer_vals) / 100)}",
    pctdistance=0.85,
    startangle=90,
    counterclock=False,
    wedgeprops=dict(width=0.3, edgecolor='white')
)

# Inner ring: unique forms (solid pie)
# The line below was changed. 'auto' was changed to 'autopct' and the lambda function was applied
wedges_inner, _, autotexts_inner = ax.pie(
    inner_vals,
    radius=0.7,
    labels=None,
    colors=colors,
    startangle=90,
    counterclock=False,
    autopct=lambda pct: f"{round(pct * sum(inner_vals) / 100)}", # This line was changed to fix the error
    pctdistance=0.6,
    wedgeprops=dict(edgecolor='white')
)

# Title and legend
ax.set_title("Short Forms by Character Length (PLOD Dataset)\nInner: Unique Forms | Outer: Total Frequency", fontsize=11)
ax.legend(wedges_outer, labels, title="Char Length", loc="center left", bbox_to_anchor=(1, 0.5), fontsize=9)
ax.axis('equal')  # Ensure the pie is a circle

plt.tight_layout()
plt.show()
